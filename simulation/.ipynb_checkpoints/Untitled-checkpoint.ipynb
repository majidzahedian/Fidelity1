# %%
from scipy.stats import poisson
import matplotlib.pyplot as plt
import numpy as np
from numpy import exp, sin, cos, sqrt, real, imag, argmax, argmin
from scipy.special import iv, i0
from scipy.integrate import quad
import tqdm

# %%
# %matplotlib notebook
n=np.arange(100)
m=np.arange(100)
plt.plot(n, poisson.pmf(n, 10)+ poisson.pmf(n, 60), '-o', ms=4, label='poisson pmf')
plt.plot(n, poisson.pmf(n, 70), '-o', ms=4, label='poisson pmf')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
P = 0.04 # mW
la1 = 20823.89228823*P  # cps
la2 = 160507.64200232*P # cps
ga1 = 3872.39255739*P*P    # Hz
ga2 = 24142.64150491 *P*P  # Hz
TR = 11e-3  # Read out time is second
print(ga2)
a=np.array([1,2,3])
a= np.append(a,5)
a
# Out:
# 38.628226407856
# array([1, 2, 3, 5])

# %%
##########################################################################################################
def integrand_i1(t,n):
    a_odd  =  ga1*iv(0,2*sqrt(ga1*ga2*t*(TR-t))) 
    a_even = sqrt(ga1*ga2*t/(TR-t))*iv(1,2*sqrt(ga1*ga2*t*(TR-t))) 
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even+a_odd)*poisson.pmf(n, la1*t+la2*(TR-t))

def P_n_Cond_i1(n):
    return quad(integrand_i1, 0, TR, args=n)[0] + exp(-ga1*TR)*poisson.pmf(n, la1*TR)
#----------------------------------
def integrand_i2(t,n):
    a_odd  =  ga2*iv(0,2*sqrt(ga1*ga2*t*(TR-t))) 
    a_even = sqrt(ga1*ga2*(TR-t)/t)*iv(1,2*sqrt(ga1*ga2*t*(TR-t)))
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even+a_odd)*poisson.pmf(n, la1*t+la2*(TR-t))

def P_n_Cond_i2(n):
    return quad(integrand_i2, 0, TR, args=n)[0] + exp(-ga2*TR)*poisson.pmf(n, la2*TR)

###############################################################################################################
def integrand_f1(t,n):
    a_odd = ga2*iv(0,2*sqrt(ga1*ga2*t*(TR-t)))
    a_even = sqrt(ga1*ga2*t/(TR-t))*iv(1,2*sqrt(ga1*ga2*t*(TR-t)))
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even*p1+a_odd*p2)*poisson.pmf(n, la1*t+la2*(TR-t))

def P_n_Cond_f1(n):
    return  quad(integrand_f1, 0, TR, args=n)[0] + exp(-ga1*TR)*p1*poisson.pmf(n, la1*TR)
#----------------------------------
def integrand_f2(t,n):
    a_odd = ga1*iv(0,2*sqrt(ga1*ga2*t*(TR-t))) 
    a_even = sqrt(ga1*ga2*(TR-t)/t)*iv(1,2*sqrt(ga1*ga2*t*(TR-t))) 
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even*p2+a_odd*p1)*poisson.pmf(n, la1*t+la2*(TR-t))
    
def P_n_Cond_f2(n):
    return  quad(integrand_f2, 0, TR, args=n)[0] + exp(-ga2*TR)*p2*poisson.pmf(n, la2*TR)
###############################################################################################################

def P_n_1(n):
    return poisson.pmf(n, la1*TR)
#----------------------------------
def P_n_2(n):
    return poisson.pmf(n, la2*TR)
##############################################################################################################
## finding intersection of two curves as threshold for fidelity
def n_th(arr1,arr2):
    i = argmax(arr1)
    j = argmax(arr2)
    return i+argmin(np.abs(arr1[i:j]-arr2[i:j]))
###############################################################################################################

def Fidelity_i():
    prob_n_Cond_i1 = np.array([])
    prob_n_Cond_i2 = np.array([])
    N = np.arange(poisson.ppf(0.0001, la1*TR),poisson.ppf(0.9999, la2*TR))
    for n in N:
        prob_n_Cond_i1 = np.append(prob_n_Cond_i1, P_n_Cond_i1(n))
        prob_n_Cond_i2 = np.append(prob_n_Cond_i2, P_n_Cond_i2(n))
        #prob_n_Cond_i1.append(P_n_Cond_i1(n))
        #prob_n_Cond_i2.append(P_n_Cond_i2(n))

    prob_n_Cond_i1 = prob_n_Cond_i1/np.trapz(prob_n_Cond_i1)
    prob_n_Cond_i2 = prob_n_Cond_i2/np.trapz(prob_n_Cond_i2)
    n_th_i = n_th(prob_n_Cond_i1,prob_n_Cond_i2)
    F_i = 1 - np.trapz(prob_n_Cond_i2[0:n_th_i+1]) - np.trapz(prob_n_Cond_i1[n_th_i:])
    return F_i
###########################################################################################################
def Fidelity_f():
    prob_n_Cond_f1 = []
    prob_n_Cond_f2 = []
    N = np.arange(poisson.ppf(0.0001, la1*TR),poisson.ppf(0.9999, la2*TR))
    for n in N:
        prob_n_Cond_f1.append(P_n_Cond_f1(n))
        prob_n_Cond_f2.append(P_n_Cond_f2(n))

    prob_n_Cond_f1 = np.array(prob_n_Cond_f1)
    prob_n_Cond_f2 = np.array(prob_n_Cond_f2)
    prob_n_Cond_f1 = prob_n_Cond_f1/np.trapz(prob_n_Cond_f1)
    prob_n_Cond_f2 = prob_n_Cond_f2/np.trapz(prob_n_Cond_f2)
    n_th_f = n_th(prob_n_Cond_f1,prob_n_Cond_f2)
    F_f = 1 - np.trapz(prob_n_Cond_f2[0:n_th_f+1]) - np.trapz(prob_n_Cond_f1[n_th_f:])
    return F_f
##################################################################################################

# %%
def integrand_Pn_even(t,n,la1,la2,g1,g2,TR):
    return exp((ga1-ga2)*t-ga1*TR)*sqrt(ga1*ga2*t/(TR-t))*iv(1,2*sqrt(ga1*ga2*t*(TR-t)))*poisson.pmf(n, la2*t+la1*(TR-t))
    
def Pn_even(n,la1,la2,g1,g2,TR): # probability to emit n photons for even jumps FROM LEVEL 2 TO LEVEL 1
    return quad(integrand_Pn_even, 0, TR, args=[n,la1,la2,g1,g2,TR])[0] + exp(-ga2*TR)*poisson.pmf(n, la2*TR)

##########################################################################################################
def integrand_Pn_odd(t,n,la1,la2,g1,g2,TR):
    return exp((ga1-ga2)*t-ga1*TR)*iv(0,2*sqrt(ga1*ga2*t*(TR-t)))*poisson.pmf(n, la2*t+la1*(TR-t))
    
def Pn_odd(n,la1,la2,g1,g2,TR): # probability to emit n photons for odd jumps FROM LEVEL 2 TO LEVEL 1
    return quad(integrand_Pn_odd, 0, TR, args=[n,la1,la2,g1,g2,TR])[0]

##########################################################################################################
def integrand_i1(t,n):
    a_odd  =  ga1*iv(0,2*sqrt(ga1*ga2*t*(TR-t))) 
    a_even = sqrt(ga1*ga2*t/(TR-t))*iv(1,2*sqrt(ga1*ga2*t*(TR-t))) 
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even+a_odd)*poisson.pmf(n, la1*t+la2*(TR-t))

def P_n_Cond_i1(n):
    return quad(integrand_i1, 0, TR, args=n)[0] + exp(-ga1*TR)*poisson.pmf(n, la1*TR)
#----------------------------------
def integrand_i2(t,n):
    a_odd  =  ga2*iv(0,2*sqrt(ga1*ga2*t*(TR-t))) 
    a_even = sqrt(ga1*ga2*(TR-t)/t)*iv(1,2*sqrt(ga1*ga2*t*(TR-t)))
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even+a_odd)*poisson.pmf(n, la1*t+la2*(TR-t))

def P_n_Cond_i2(n):
    return quad(integrand_i2, 0, TR, args=n)[0] + exp(-ga2*TR)*poisson.pmf(n, la2*TR)

###############################################################################################################
def integrand_f1(t,n):
    a_odd = ga2*iv(0,2*sqrt(ga1*ga2*t*(TR-t)))
    a_even = sqrt(ga1*ga2*t/(TR-t))*iv(1,2*sqrt(ga1*ga2*t*(TR-t)))
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even*p1+a_odd*p2)*poisson.pmf(n, la1*t+la2*(TR-t))

def P_n_Cond_f1(n):
    return  quad(integrand_f1, 0, TR, args=n)[0] + exp(-ga1*TR)*p1*poisson.pmf(n, la1*TR)
#----------------------------------
def integrand_f2(t,n):
    a_odd = ga1*iv(0,2*sqrt(ga1*ga2*t*(TR-t))) 
    a_even = sqrt(ga1*ga2*(TR-t)/t)*iv(1,2*sqrt(ga1*ga2*t*(TR-t))) 
    return exp((ga2-ga1)*t)*exp(-ga2*TR)*(a_even*p2+a_odd*p1)*poisson.pmf(n, la1*t+la2*(TR-t))
    
def P_n_Cond_f2(n):
    return  quad(integrand_f2, 0, TR, args=n)[0] + exp(-ga2*TR)*p2*poisson.pmf(n, la2*TR)
###############################################################################################################

def P_n_1(n):
    return poisson.pmf(n, la1*TR)
#----------------------------------
def P_n_2(n):
    return poisson.pmf(n, la2*TR)
##############################################################################################################
## finding intersection of two curves as threshold for fidelity
def n_th(arr1,arr2):
    i = argmax(arr1)
    j = argmax(arr2)
    return i+argmin(np.abs(arr1[i:j]-arr2[i:j]))
###############################################################################################################

def Fidelity_i(la1,la2,g1,g2,TR):
    prob_n_Cond_i1 = np.array([])
    prob_n_Cond_i2 = np.array([])
    N = np.arange(poisson.ppf(0.0001, la1*TR),poisson.ppf(0.9999, la2*TR))
    for n in N:
        prob_n_Cond_i1 = np.append(prob_n_Cond_i1, P_n_Cond_i1(n))
        prob_n_Cond_i2 = np.append(prob_n_Cond_i2, P_n_Cond_i2(n))
        #prob_n_Cond_i1.append(P_n_Cond_i1(n))
        #prob_n_Cond_i2.append(P_n_Cond_i2(n))

    prob_n_Cond_i1 = prob_n_Cond_i1/np.trapz(prob_n_Cond_i1)
    prob_n_Cond_i2 = prob_n_Cond_i2/np.trapz(prob_n_Cond_i2)
    n_th_i = n_th(prob_n_Cond_i1,prob_n_Cond_i2)
    F_i = 1 - np.trapz(prob_n_Cond_i2[0:n_th_i+1]) - np.trapz(prob_n_Cond_i1[n_th_i:])
    return F_i
###########################################################################################################
def Fidelity_f():
    prob_n_Cond_f1 = []
    prob_n_Cond_f2 = []
    N = np.arange(poisson.ppf(0.0001, la1*TR),poisson.ppf(0.9999, la2*TR))
    for n in N:
        prob_n_Cond_f1.append(P_n_Cond_f1(n))
        prob_n_Cond_f2.append(P_n_Cond_f2(n))

    prob_n_Cond_f1 = np.array(prob_n_Cond_f1)
    prob_n_Cond_f2 = np.array(prob_n_Cond_f2)
    prob_n_Cond_f1 = prob_n_Cond_f1/np.trapz(prob_n_Cond_f1)
    prob_n_Cond_f2 = prob_n_Cond_f2/np.trapz(prob_n_Cond_f2)
    n_th_f = n_th(prob_n_Cond_f1,prob_n_Cond_f2)
    F_f = 1 - np.trapz(prob_n_Cond_f2[0:n_th_f+1]) - np.trapz(prob_n_Cond_f1[n_th_f:])
    return F_f
##################################################################################################

# %%
P = 0.01888 # mW
la1 = 20823.89228823*P  # cps
la2 = 160507.64200232*P # cps
ga1 = 3872.39255739*P*P    # Hz
ga2 = 24142.64150491 *P*P  # Hz
TR = 5e-3  # Read out time is second
p2 = ga1/(ga1+ga2)
#p2 = 0.75
p1 = 1-p2
print(p1,p2)
prob_n_Cond_i1 = []
prob_n_Cond_i2 = []
prob_n_Cond_f1 = []
prob_n_Cond_f2 = []
prob_n_1 = []
prob_n_2 = []
N = np.arange(poisson.ppf(0.0001, la1*TR),poisson.ppf(0.9999, la2*TR))
for n in tqdm.tqdm_notebook(N):
    prob_n_Cond_i1.append(P_n_Cond_i1(n))
    prob_n_Cond_i2.append(P_n_Cond_i2(n))
    prob_n_Cond_f1.append(P_n_Cond_f1(n))
    prob_n_Cond_f2.append(P_n_Cond_f2(n))
    prob_n_1.append(P_n_1(n))
    prob_n_2.append(P_n_2(n))

prob_n_1 = np.array(prob_n_1)
prob_n_2 = np.array(prob_n_2)
prob_n_Cond_i1 = np.array(prob_n_Cond_i1)
prob_n_Cond_i2 = np.array(prob_n_Cond_i2)
prob_n_Cond_f1 = np.array(prob_n_Cond_f1)
prob_n_Cond_f2 = np.array(prob_n_Cond_f2)

prob_n_Cond_f1 = prob_n_Cond_f1/np.trapz(prob_n_Cond_f1)
prob_n_Cond_f2 = prob_n_Cond_f2/np.trapz(prob_n_Cond_f2)
prob_n_Cond_i1 = prob_n_Cond_i1/np.trapz(prob_n_Cond_i1)
prob_n_Cond_i2 = prob_n_Cond_i2/np.trapz(prob_n_Cond_i2)
# Out:
# 0.8617744833442447 0.13822551665575528
# C:\Users\majid\AppData\Local\Temp\ipykernel_28336\3982620779.py:18: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for n in tqdm.tqdm_notebook(N):
#   0%|          | 0/32 [00:00<?, ?it/s]

# %%
plt.figure(dpi=100)
plt.plot(N, prob_n_1, '-o', ms=3, label='NV0')
plt.plot(N, prob_n_2, '-o', ms=3, label='NV-')
plt.vlines(6,ymin=0, ymax=max(prob_n_1), color='black',label='Threshold')
plt.plot(N, prob_n_Cond_i1, '-o', ms=3, label='Init NV0')
plt.plot(N, prob_n_Cond_i2, '-o', ms=3, label='Init NV-')
plt.title('P= {} uW'.format(1e-3*round(P*1e6))+', TR= {} ms'.format(TR*1e3), fontsize=16)
plt.legend(fontsize=12)
plt.xlabel('Photon Number', fontsize=16)
plt.ylabel('Histogram', fontsize=16)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Histogram')

# %%
plt.figure()
#plt.plot(N, prob_n_Cond_i1, '-o', ms=3, label='cond ini 1')
#plt.plot(N, prob_n_Cond_i2, '-o', ms=3, label='cond ini 2')
plt.plot(N, prob_n_Cond_f1, '-o', ms=3, label='final NV0')
plt.plot(N, prob_n_Cond_f2, '-o', ms=3, label='final NV-')
plt.vlines(7,ymin=0, ymax=max(prob_n_Cond_f1), color='black',label='Threshold')
plt.legend(fontsize=12)
plt.xlabel('Photon Number', fontsize=16)
plt.ylabel('Histogram', fontsize=16)
plt.title('P= {} uW'.format(1e-3*round(P*1e6))+', TR= {} ms'.format(TR*1e3), fontsize=16)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'P= 18.88 uW, TR= 5.0 ms')

# %%
# integral below curves
print(np.trapz(prob_n_1))
print(np.trapz(prob_n_2))
print(np.trapz(prob_n_Cond_i1))
print(np.trapz(prob_n_Cond_i2))
print(np.trapz(prob_n_Cond_f1))
print(np.trapz(prob_n_Cond_f2))
# Out:
# 0.9999067565848848
# 0.9998857541099471
# 0.9999999999999999
# 0.9999999999999999
# 0.9999999999999999
# 1.0

# %%
### fidelity
n_th_s = n_th(prob_n_1,prob_n_2)
n_th_i = n_th(prob_n_Cond_i1,prob_n_Cond_i2)
n_th_f = n_th(prob_n_Cond_f1,prob_n_Cond_f2)
F_s = 1 - np.trapz(prob_n_2[0:n_th_i+1]) - np.trapz(prob_n_1[n_th_i:])
F_i = 1 - np.trapz(prob_n_Cond_i2[0:n_th_i+1]) - np.trapz(prob_n_Cond_i1[n_th_i:])
F_f = 1 - np.trapz(prob_n_Cond_f2[0:n_th_f+1]) - np.trapz(prob_n_Cond_f1[n_th_f:])
print(F_s)
print(F_i)
print(F_f)
# Out:
# 0.9998797219043724
# 0.9950012514597978
# 0.9870961600523197

# %%
n_th_i + poisson.ppf(0.0001, la1*TR)
# Out:
# 66.0

# %% [markdown]
# # Fidelity as a function of power, 1D

# %%
Fs=[]
PP = np.linspace(0.001,0.05,20)
TR = 10e-3
for P in tqdm.tqdm_notebook(PP):
    la1 = 20823.89228823*P  # cps
    la2 = 160507.64200232*P # cps
    ga1 = 3872.39255739*P*P   # Hz
    ga2 = 24142.64150491*P*P  # Hz
    i = Fidelity_i()
    Fs.append(i)

plt.figure()
plt.plot(PP, np.array(Fs), '-o', ms=3, label='cond fin 1')
#plt.legend(fontsize=12)
plt.xlabel('Power (mW)', fontsize=16)
plt.ylabel('Fidelity', fontsize=16)
# Out:
# C:\Users\yy3\AppData\Local\Temp\ipykernel_22180\1295944279.py:4: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for P in tqdm.tqdm_notebook(PP):
#   0%|          | 0/20 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="640">
# Text(0, 0.5, 'Fidelity')

# %% [markdown]
# # Fidelity for initial states

# %%
F_2d_i=[]
PP = np.linspace(0.015,0.05,10)
for P in tqdm.tqdm_notebook(PP):
    la1 = 20823.89228823*P  # cps
    la2 = 160507.64200232*P # cps
    ga1 = 3872.39255739*P*P   # Hz
    ga2 = 24142.64150491*P*P  # Hz
    p1 = ga2/(ga1+ga2)
    p2 = ga1/(ga1+ga2)
    F_1d=[]
    TTR = np.linspace(1e-3,5e-3,20)
    for TR in TTR:
        F_1d.append(Fidelity_i())
    F_2d_i.append(F_1d)
F_2d_i=np.array(F_2d_i)
# Out:
# C:\Users\majid\AppData\Local\Temp\ipykernel_28336\1265745141.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for P in tqdm.tqdm_notebook(PP):
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
time,power=np.meshgrid(TTR, PP)
opt_F = np.max(F_2d_i)
print("Max Fidelity = {}".format(opt_F))
result=np.where(F_2d_i == np.amax(F_2d_i))
listOfCordinates = list(zip(result[0], result[1]))
for cord in listOfCordinates:
    if F_2d_i[cord[0]][cord[1]]==np.max(F_2d_i):
        opt_p = power[cord[0]][cord[1]]
        opt_t = time[cord[0]][cord[1]]
        print('Optimum power = {} uW'.format(opt_p*1000))
        print('Optimum time = {} ms'.format(opt_t*1000))
    else: print('max did not calculated correctly')
   
plt.figure(dpi=100)
plt.contourf(power*1000, time*1000, F_2d_i,80)
plt.title('Fidelity (orange, initial=final)', fontsize =18)
plt.plot(opt_p*1000, opt_t*1000, '*', ms=10, color='red', label='Optimum')
plt.xlabel('Power (uW)', fontsize=16)
plt.ylabel('Readout Time (ms)', fontsize =16)
plt.colorbar()
plt.legend()
#plt.savefig("F_initial_state.png",dpi=150)

plt.figure()
plt.plot(N, prob_n_Cond_f1, '-o', ms=3, label='final NV0')
plt.plot(N, prob_n_Cond_f2, '-o', ms=3, label='final NV-')
plt.vlines(6,ymin=0, ymax=max(prob_n_Cond_f1), color='black',label='Threshold')
plt.legend(fontsize=12)
plt.xlabel('Photon Number', fontsize=16)
plt.ylabel('Histogram', fontsize=16)
plt.title('P= {} uW'.format(1e-3*round(opt_p*1e6))+', TR= {} ms'.format(opt_t*1e3)
          +', F= {} %'.format(round(opt_F*1e4)*1e-2), fontsize=16)
# Out:
# Max Fidelity = 0.9658977358262637
# Optimum power = 10.000000000000002 uW
# Optimum time = 5.0 ms
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'P= 10.0 uW, TR= 5.0 ms, F= 96.59 %')

# %% [markdown]
# # Fidelity for final states (same as before for orange)

# %%
F_2d_f=[]
PP = np.linspace(0.0004,0.0007,10)
for P in tqdm.tqdm_notebook(PP):
    la1 = 20823.89228823*P  # cps
    la2 = 160507.64200232*P # cps
    ga1 = 3872.39255739*P*P   # Hz
    ga2 = 24142.64150491*P*P  # Hz
    p1 = ga2/(ga1+ga2)
    p2 = ga1/(ga1+ga2)
    F_1d=[]
    TTR = np.linspace(350e-3,450e-3,20)
    for TR in TTR:
        F_1d.append(Fidelity_f())
    F_2d_f.append(F_1d)
F_2d_f=np.array(F_2d_f)
# Out:
# C:\Users\yy3\AppData\Local\Temp\ipykernel_22180\1785792441.py:3: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for P in tqdm.tqdm_notebook(PP):
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
time,power=np.meshgrid(TTR, PP)
opt_F = np.max(F_2d_f)
print("Max Fidelity = {}".format(opt_F))
result=np.where(F_2d_f == np.amax(F_2d_f))
listOfCordinates = list(zip(result[0], result[1]))
for cord in listOfCordinates:
    if F_2d_f[cord[0]][cord[1]]==np.max(F_2d_f):
        print('Optimum power = {} uW'.format(power[cord[0]][cord[1]]*1000))
        print('Optimum time = {} ms'.format(time[cord[0]][cord[1]]*1000))
    else: print('max did not calculated correctly')
   
plt.figure(dpi=100)
plt.contourf(power*1000, time*1000, F_2d_f,500)
plt.title('Fidelity for orange initialization', fontsize =18)
plt.xlabel('Power (uW)', fontsize=16)
plt.ylabel('Readout Time (ms)', fontsize =16)
plt.colorbar()
#plt.savefig("F_orange_init.png",dpi=150)
# Out:
# Max Fidelity = 0.9987438833476447
# Optimum power = 0.43333333333333335 uW
# Optimum time = 450.0 ms
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# # Fidelity for final states, Green initialization

# %%
F_2d_f=[]
p1 = 0.25
p2 = 0.75
PP = np.linspace(0.007,0.05,10)
for P in tqdm.tqdm_notebook(PP):
    la1 = 20823.89228823*P  # cps
    la2 = 160507.64200232*P # cps
    ga1 = 3872.39255739*P*P   # Hz
    ga2 = 24142.64150491*P*P  # Hz
    F_1d=[]
    TTR = np.linspace(1.5e-3,7e-3,20)
    for TR in TTR:
        F_1d.append(Fidelity_f())
    F_2d_f.append(F_1d)
F_2d_f=np.array(F_2d_f)
# Out:
# C:\Users\majid\AppData\Local\Temp\ipykernel_28336\2209792287.py:5: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for P in tqdm.tqdm_notebook(PP):
#   0%|          | 0/10 [00:00<?, ?it/s]

# %%
time,power=np.meshgrid(TTR, PP)
opt_F = np.max(F_2d_f)
print("Max Fidelity = {}".format(opt_F))
result=np.where(F_2d_f == np.amax(F_2d_f))
listOfCordinates = list(zip(result[0], result[1]))
for cord in listOfCordinates:
    if F_2d_f[cord[0]][cord[1]]==np.max(F_2d_f):
        opt_p = power[cord[0]][cord[1]]
        opt_t = time[cord[0]][cord[1]]
        print('Optimum power = {} uW'.format(power[cord[0]][cord[1]]*1000))
        print('Optimum time = {} ms'.format(time[cord[0]][cord[1]]*1000))
    else: print('max did not calculated correctly')
   
plt.figure(dpi=100)
plt.contourf(power*1000, time*1000, F_2d_f,50)
plt.title('Fidelity for Green initialization', fontsize =18)
plt.plot(opt_p*1000, opt_t*1000, '*', ms=10, color='red', label='Optimum')
plt.xlabel('Power (uW)', fontsize=16)
plt.ylabel('Readout Time (ms)', fontsize =16)
plt.colorbar()
#plt.savefig("F_green_init.png",dpi=150)
P,TR = 0.04, 0.003
la1 = 20823.89228823*P  # cps
la2 = 160507.64200232*P # cps
ga1 = 3872.39255739*P*P   # Hz
ga2 = 24142.64150491*P*P  # Hz
opt_F = Fidelity_f()
print(opt_F)
plt.figure()
plt.plot(N, prob_n_Cond_f1, '-o', ms=3, label='final NV0')
plt.plot(N, prob_n_Cond_f2, '-o', ms=3, label='final NV-')
plt.vlines(6,ymin=0, ymax=max(prob_n_Cond_f1), color='black',label='Threshold')
plt.legend(fontsize=12)
plt.xlabel('Photon Number', fontsize=16)
plt.ylabel('Histogram', fontsize=16)
plt.title('P= {} uW'.format(1e-3*round(opt_p*1e6))+', TR= {} ms'.format(round(opt_t*1e5)*1e-2)
          +', F= {} %'.format(round(opt_F*1e3)*1e-1), fontsize=16)
# Out:
# Max Fidelity = 0.9367164370600384
# Optimum power = 11.777777777777779 uW
# Optimum time = 7.0 ms
# <img src="data:image/png;base64,..." width="640">
# 0.9435494983424464
# <img src="data:image/png;base64,..." width="640">
# Text(0.5, 1.0, 'P= 11.778 uW, TR= 7.0 ms, F= 94.4 %')
